# %%
# IMPORTS
import cvxpy as cp
import numpy as np
import numpy.linalg
import numpy.matlib
from numpy.linalg import norm
import algorithms.ssplines_R as ssplinesR
from scipy import interpolate
from scipy import signal
import csv   
import matplotlib.pyplot as plt
import pandas as pd

# %%
# LOAD DATA

# 1) LOAD DYNAMICS AND TIME ARRAYS

filepath = 'data_files/Lorenz63_dynamics.csv'
dynamics = np.genfromtxt(filepath, delimiter=',')

t = dynamics[0]
data = dynamics[1:]
n_states = int(data.shape[0] / 2)
X = data[0:n_states]
DX = data[n_states:]
t_samples = len(t)

noise_lvls = [0.001, 0.01, 0.1, 1]
n_noise_lvls = len(noise_lvls)

mean_X_error = np.zeros((n_states, n_noise_lvls))
mean_dX_error = np.zeros((n_states, n_noise_lvls))

var_X_error = np.zeros((n_states, n_noise_lvls))
var_dX_error = np.zeros((n_states, n_noise_lvls))  

write_data = False

for noise, sigma in enumerate(noise_lvls):

    # 2) LOAD OBSERVATION SAMPLES
    Y_samples = []
    noise_lvl = str(sigma)

    for state in range(n_states):

        filepath = 'data_files/Lorenz63_samples_noise_' + noise_lvl +'_Y'+ str(state+1) + '.csv'
        y = np.genfromtxt(filepath, delimiter=',')

        Y_samples.append(y)

    n_samples = Y_samples[0].shape[0]

    ################### DENOISING AND NUMERICAL DIFFERENTIATION - SMOOTHING SPLINES ###################
    trim = int(np.floor(5 / 100 * t_samples))
    error_X = np.zeros((n_samples,n_states))
    error_dX = np.zeros((n_samples,n_states))
    tt_samples = t_samples - 2 * trim
    Yhat_ss = np.zeros((n_samples, tt_samples))
    DYhat_ss = np.zeros((n_samples, tt_samples))

    for state in range(n_states):

        for sample in range(n_samples):
        #CVX code
            y = Y_samples[state][sample,:]

            #Find corner point
            ss_lc = ssplinesR.lcurve_corner(y, t, lambda_min = 1e-8, lambda_max = 1)
            y_ss = ss_lc[0]
            dy_ss = ss_lc[1]
            #Remove ends
            Yhat_ss[sample,:] = y_ss[trim:-trim]
            DYhat_ss[sample,:] = dy_ss[trim:-trim]
            #Compute errors
            error_X[sample,state] = norm(Yhat_ss[sample,:] - X[state,trim:-trim]) / norm(X[state,trim:-trim])
            error_dX[sample,state] = norm(DYhat_ss[sample,:] - DX[state,trim:-trim]) / norm(DX[state,trim:-trim])
        
        if write_data:
            filename_y = 'data_files/Lorenz63_ssplines_' + noise_lvl + '_Y' + str(state+1) + '.csv'
            filename_dy = 'data_files/Lorenz63_ssplines_' + noise_lvl + '_dY' + str(state+1) + '.csv'
            with open(filename_y, 'w') as csvfile:   
                # creating a csv writer object   
                csvwriter = csv.writer(csvfile)   
                # writing the data rows   
                csvwriter.writerows(Yhat_ss)
            with open(filename_dy, 'w') as csvfile:   
                # creating a csv writer object   
                csvwriter = csv.writer(csvfile)   
                # writing the data rows   
                csvwriter.writerows(DYhat_ss)

        mean_X_error[state, noise] = error_X[:,state].mean()
        mean_dX_error[state, noise] = error_dX[:,state].mean()
        var_X_error[state, noise] = error_X[:,state].var()
        var_dX_error[state, noise] = error_dX[:,state].var()
# Out:
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 14 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 6 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 8 iterations.
#   Convergence criterion reached in 4 iterations.
#   Convergence criterion reached in 8 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 7 iterations.
#   Convergence criterion reached in 6 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 6 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 8 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 7 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 7 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 8 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 8 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 3 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 8 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 8 iterations.
#   Convergence criterion reached in 7 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 6 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 8 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 0 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 10 iterations.
#   Convergence criterion reached in 9 iterations.
#   Convergence criterion reached in 11 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 13 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 12 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 15 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.

# %%
temp = [['$\sigma$ = ' + str(x)] * n_states for x in noise_lvls]
noise_indx = np.array([item for sublist in temp for item in sublist])

state_indx = np.array(['state x' + str(x+1) for x in range(n_states)] * n_noise_lvls)

arrays = [noise_indx, state_indx]
data = np.vstack((mean_X_error.T.flatten(), var_X_error.T.flatten(), mean_dX_error.T.flatten(), var_dX_error.T.flatten())).T

col_names = ['mean error x', 'var. error x', 'mean error dx', 'var. error dx']
df = pd.DataFrame(data, index=arrays, columns=col_names)
df
# Out:
#                            mean error x  var. error x  mean error dx  \
# $\sigma$ = 0.001 state x1      0.000090  3.513377e-11       0.001303
#                  state x2      0.000110  3.735391e-11       0.001475
#                  state x3      0.000048  6.321981e-12       0.001133
# $\sigma$ = 0.01  state x1      0.000705  2.719581e-09       0.007832
#                  state x2      0.000623  2.709927e-09       0.006007
#                  state x3      0.000251  3.160331e-10       0.004556
# $\sigma$ = 0.1   state x1      0.005802  3.813068e-07       0.047608
#                  state x2      0.005104  2.468649e-07       0.036465
#                  state x3      0.002062  4.081479e-08       0.027776
# $\sigma$ = 1     state x1      0.039848  3.360636e-05       0.148922
#                  state x2      0.037407  2.004617e-05       0.147111
#                  state x3      0.015523  3.823199e-06       0.114896
#
#                            var. error dx
# $\sigma$ = 0.001 state x1   5.737695e-09
#                  state x2   1.624135e-09
#                  state x3   6.896785e-10
# $\sigma$ = 0.01  state x1   4.695223e-07
#                  state x2   2.286724e-07
#                  state x3   1.272390e-07
# $\sigma$ = 0.1   state x1   2.946975e-05
#                  state x2   1.326931e-05
#                  state x3   5.026894e-06
# $\sigma$ = 1     state x1   4.031380e-04
#                  state x2   2.239949e-04
#                  state x3   1.740802e-04
