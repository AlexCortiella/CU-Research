# %%
# IMPORTS
import cvxpy as cp
import numpy as np
import numpy.linalg
import numpy.matlib
from numpy.linalg import norm
import algorithms.trend_filter_derivative_pkg as tfilter
from scipy import interpolate
from scipy import signal
import csv   
import matplotlib.pyplot as plt
import pandas as pd

# %%
# LOAD DATA

# 1) LOAD DYNAMICS AND TIME ARRAYS

filepath = 'data_files/Lorenz63_dynamics.csv'
dynamics = np.genfromtxt(filepath, delimiter=',')

t = dynamics[0]
data = dynamics[1:]
n_states = int(data.shape[0] / 2)
X = data[0:n_states]
DX = data[n_states:]
t_samples = len(t)

noise_lvls = [0.01]
n_noise_lvls = len(noise_lvls)

mean_X_error = np.zeros((n_states, n_noise_lvls))
mean_dX_error = np.zeros((n_states, n_noise_lvls))

var_X_error = np.zeros((n_states, n_noise_lvls))
var_dX_error = np.zeros((n_states, n_noise_lvls))  

for noise in range(n_noise_lvls):

    # 2) LOAD OBSERVATION SAMPLES
    Y_samples = []
    noise_lvl = str(noise_lvls[noise])

    for state in range(n_states):

        filepath = 'data_files/Lorenz63_samples_noise_' + noise_lvl +'_Y'+ str(state+1) + '.csv'
        y = np.genfromtxt(filepath, delimiter=',')

        Y_samples.append(y)

    n_samples = Y_samples[0].shape[0]

    ################### DENOISING AND NUMERICAL DIFFERENTIATION - SMOOTHING SPLINES ###################
    trim = int(np.floor(5 / 100 * t_samples))
    error_dX = np.zeros((n_samples,n_states))
    tt_samples = t_samples - 2 * trim
    DYhat_tf = np.zeros((n_samples, tt_samples))

    for state in range(n_states):

        for sample in range(n_samples):
        #CVX code
            y = Y_samples[state][sample,:]

            #Find corner point
            tf_lc = tfilter.lcurve_corner(y, t, order = 3, lambda_min = 1e-5, lambda_max = 1)
            dy_tf = tf_lc[0]
            
            #Remove ends
            DYhat_tf[sample,:] = dy_tf[trim:-trim]
            #Compute errors
            error_dX[sample,state] = norm(DYhat_tf[sample,:] - DX[state,trim:-trim]) / norm(DX[state,trim:-trim])
            
        filename_dy = 'data_files/trendfilter_diff/Lorenz63_trendfilter_diff_' + noise_lvl + '_dY' + str(state+1) + '.csv'
        with open(filename_dy, 'w') as csvfile:   
            # creating a csv writer object   
            csvwriter = csv.writer(csvfile)   
            # writing the data rows   
            csvwriter.writerows(DYhat_tf)

        mean_dX_error[state, noise] = error_dX[:,state].mean()
        var_dX_error[state, noise] = error_dX[:,state].var()
# Out:
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 16 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 17 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 19 iterations.
#   Convergence criterion reached in 18 iterations.
#   Convergence criterion reached in 19 iterations.
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# <ipython-input-3-7946b7aa477c> in <module>
#      50
#      51             #Find corner point
# ---> 52             tf_lc = tfilter.lcurve_corner(y, t, order = 3, lambda_min = 1e-5, lambda_max = 1)
#      53             dy_tf = tf_lc[0]
#      54
#
# ~/Desktop/PhD_Research/Research_GitHub/CU-Research/Python_Codes/Numerical_Differentiation/Lorenz63/algorithms/trend_filter_derivative_cvx.py in lcurve_corner(y, x, order, lambda_max, lambda_min, epsilon, max_iter, normalize, verbose)
#     209
#     210     #Check the range of lambdas and compute normalization coefficients
# --> 211     lambda_max, lambda_min = check_lambdas(lambda_min, lambda_max, y, x)
#     212
#     213     lambda_vec = np.array([lambda_min, lambda_max, 0, 0])
#
# ~/Desktop/PhD_Research/Research_GitHub/CU-Research/Python_Codes/Numerical_Differentiation/Lorenz63/algorithms/trend_filter_derivative_cvx.py in check_lambdas(lambda_min, lambda_max, y, x, order, tol)
#      76 #             break
#      77
# ---> 78     out = trend_filter_der(y, x, lambd = lambda_max, order = order)
#      79     residual_max, reg_residual_min = out[1]
#      80     out = trend_filter_der(y, x, lambd = lambda_min, order = order)
#
# ~/Desktop/PhD_Research/Research_GitHub/CU-Research/Python_Codes/Numerical_Differentiation/Lorenz63/algorithms/trend_filter_derivative_cvx.py in trend_filter_der(y, x, lambd, order, verbose)
#     177
#     178     prob = cp.Problem(obj)
# --> 179     prob.solve(solver=cp.CVXOPT, verbose=verbose)
#     180
#     181     if verbose:
#
# ~/anaconda3/lib/python3.7/site-packages/cvxpy/problems/problem.py in solve(self, *args, **kwargs)
#     394         else:
#     395             solve_func = Problem._solve
# --> 396         return solve_func(self, *args, **kwargs)
#     397
#     398     @classmethod
#
# ~/anaconda3/lib/python3.7/site-packages/cvxpy/problems/problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, **kwargs)
#     752         solution = solving_chain.solve_via_data(
#     753             self, data, warm_start, verbose, kwargs)
# --> 754         self.unpack_results(solution, solving_chain, inverse_data)
#     755         return self.value
#     756
#
# ~/anaconda3/lib/python3.7/site-packages/cvxpy/problems/problem.py in unpack_results(self, solution, chain, inverse_data)
#    1066             raise error.SolverError(
#    1067                     "Solver '%s' failed. " % chain.solver.name() +
# -> 1068                     "Try another solver, or solve with verbose=True for more "
#    1069                     "information.")
#    1070         self.unpack(solution)
#
# SolverError: Solver 'CVXOPT' failed. Try another solver, or solve with verbose=True for more information.

# %%
temp = [['$\sigma$ = ' + str(x)] * n_states for x in noise_lvls]
noise_indx = np.array([item for sublist in temp for item in sublist])

state_indx = np.array(['state x' + str(x+1) for x in range(n_states)] * n_noise_lvls)

arrays = [noise_indx, state_indx]
data = np.vstack((mean_X_error.T.flatten(), var_X_error.T.flatten(), mean_dX_error.T.flatten(), var_dX_error.T.flatten())).T

col_names = ['mean error dx', 'var. error dx']
df = pd.DataFrame(data, index=arrays, columns=col_names)
df
# Out:
#                            mean error x  var. error x  mean error dx  \
# $\sigma$ = 0.001 state x1      0.000099  4.444099e-11       0.001942
#                  state x2      0.000085  2.288925e-11       0.001359
#                  state x3      0.000034  4.366856e-12       0.001048
#
#                            var. error dx
# $\sigma$ = 0.001 state x1   2.406684e-08
#                  state x2   9.600228e-09
#                  state x3   6.427273e-09

# %%
#cHEAT SHEET

#lambda_min = 1e-8, lambda_max = 1000
